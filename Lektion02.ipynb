# %% [markdown]
# # Lektion 2

# %%
from sympy import *
init_printing()

# %% [markdown]
# ## Vereinfachungen

# %%
x = Symbol('x')
y = Symbol('y')
f = (x - y) * (x + y)
f

# %%
f.expand()

# %%
expand(f)

# %%
fe = f.expand()
fe

# %%
fe.factor()

# %%
g = (x**2-y**2)/(x-y)**2
g

# %%
g.ratsimp()

# %%
g.factor()

# %%
g.simplify()

# %%
h = x*x**y
h

# %%
h.powsimp()

# %%
hp = h.simplify()
hp

# %%
hp.expand()

# %%
f = (sin(2*x)+cos(x)) / ((sin(2*x)**2 - cos(x)**2)*(sin(2*x)-cos(x)))
f

# %%
f.ratsimp()

# %%
f.trigsimp()

# %%
f.simplify()

# %%
f.expand()

# %%
f.expand(trig=True)

# %%
f.expand(trig=True, numer=True)

# %%
fe = f.expand(trig=True,numer=True).expand(trig=True,denom=True)
fe

# %%
fe.factor()

# %%
f.expand(gibtsnich=True)

# %% [markdown]
# ## Auswertungen von Ausdrücken

# %%
x = Symbol('x')
a = (9*x**2-5)/((x-2)*(x-3))
a

# %%
a.subs(x, 4)

# %%
y = Symbol('y')
b = (x-y)**3 / (x+y)
b

# %%
b.subs(x, 3).subs(y, 0)

# %%
a.subs(x, 2)

# %%
c = 1/cos(x*pi/2)
c

# %%
c.subs(x,1)

# %% [markdown]
# ## Grenzwerte

# %%
a.limit(x, 2)

# %%
a.limit(x, 2, dir='-')

# %%
a = cos(pi*x)/(2*x-1)
a

# %%
a.limit(x, Rational(1,2))

# %%
a.subs(x, Rational(1,2))

# %% [markdown]
# Wir prüfen das mit de l'Hôpital

# %%
an = numer(a)    # keine Methode
an

# %%
an_d = an.diff(x)
an_d.subs(x, Rational(1,2))

# %%
ad = denom(a)
ad_d = ad.diff(x)
ad_d.subs(x, Rational(1,2))

# %%
n = Symbol('n')
b = factorial(n)*exp(n)/n**n/sqrt(n)
b

# %%
b.limit(n, oo)

# %% [markdown]
# Stirlingsche Formel

# %% [markdown]
# ## Ableitungen

# %%
f = x**n
f

# %%
f.diff(x)

# %%
f.diff(x).powsimp()

# %%
f.diff(x,x,x).factor()

# %%
f.diff(x,3).factor()

# %%
f.diff()

# %%
f.diff(x,0)

# %%
g = x**2*cos(2*x)
g.diff()

# %% [markdown]
# So ist das Leben.

# %%
a

# %% [markdown]
# Wir berechnen den Grenzwert zu Fuß mit der Regel von de l'Hôpital

# %%
zaehler = numer(a)
nenner = denom(a)
zaehler, nenner

# %%
d_zaehler = zaehler.diff(x)
d_nenner = nenner.diff(x)
d_zaehler, d_nenner

# %%
d_zaehler.subs(x, Rational(1,2)) / d_nenner.subs(x, Rational(1,2))

# %% [markdown]
# ## unbestimmte Integrale

# %%
f

# %%
f.integrate(x)

# %%
f.integrate(x, conds='none')

# %%
f = sin(2*x)*cos(3*x)**2
f

# %%
I1 = f.integrate()   # warum darf diese Variable nicht I heißen?
I1

# %%
I1.diff(x)

# %%
I1.diff(x) == f

# %%
g = 1/(1+x**4)
I2 = g.integrate(x)
I2

# %%
I2.diff(x)

# %%
I2.diff() == g

# %%
I2.diff().ratsimp()

# %% [markdown]
# ## bestimmte Integrale

# %%
f

# %%
I2 = f.integrate((x,0,pi/4))
I2

# %%
I3 = Integral(f, (x,0,pi/4))
I3

# %%
I3.doit()

# %%
I3.n()  # numerische Integration

# %%
I4 = Integral(sqrt(exp(x)+4), (x,0,1))
I4

# %%
I4.doit()

# %%
# %%timeit
I4.n()

# %% [markdown]
# Vergleich mit der Methode aus der CompLA (nicht prüfungsrelevant für CompAna)

# %%
import numpy as np
from scipy import integrate

# %%
def f(x):
    return np.sqrt(np.exp(x)+4)

# %%
# %%timeit
res, err = integrate.quad(f, 0, 1)
res

# %% [markdown]
# ## Annahmen

# %%
a = Symbol('a')
I5 = Integral(x*exp(-a*x), (x,0,oo))
I5

# %%
I5.doit()

# %% [markdown]
# Annahmen über die Variablen

# %%
a = Symbol('a', positive=True)

# %%
sqrt(a**2)

# %%
I5.doit()  # das a in I5 wurde nicht verändert

# %%
I6 = Integral(x*exp(-a*x), (x,0,oo))  # neues I5
I6.doit()

# %%
a._assumptions

# %%
n = Symbol('n', integer=True)
cos(pi*n)

# %% [markdown]
# ## Summen und Reihen

# %%
n = Symbol('n')
j = Symbol('j')
q = Symbol('q')

# %%
S1 = Sum(j, (j,1,n))
S1

# %%
S1.doit().factor()

# %%
S2 = Sum(1/j**2, (j, 1, oo))
S2

# %%
S2.doit()

# %%
S2 = Sum(q**j, (j, 0, oo))
S2

# %%
S2.doit()

# %% [markdown]
# Da kommen wir augenblicklich nur mit einem bösen Hack dran:

# %%
S2.doit().args[0][0]

# %% [markdown]
# ## Sympy rechnet komplex

# %%
x = Symbol('x')
y = Symbol('y')
z = x+I*y
z

# %%
w = z**4
w

# %%
re(w).expand()

# %%
x = Symbol('x', real=True)
y = Symbol('y', real=True)
z = x+I*y
z

# %%
w = z**4
re(w)

# %% [markdown]
# ## Ausdrücke und Funktionen

# %%
g = sin(x)/(1+x**2)   # Ausdruck
g

# %%
def f(x):          # Funktion
    return sin(x)/(1+x++2)
f

# %%
f(x)

# %%
f(y)

# %%
f(pi)

# %%
f(2.)

# %%
g.subs(x, 2.)

# %%
F = lambdify(x, g)     # Verwandlung in eine numerisch nutzbare Funktion
F

# %%
F(2)
